# %%
import requests

url = "https://montanaflynn-fifa-world-cup.p.rapidapi.com/games"

headers = {
    'accepts': "json",
    'x-rapidapi-host': "montanaflynn-fifa-world-cup.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# {"message":"Invalid API key. Go to https:\/\/docs.rapidapi.com\/docs\/keys for more info."}

# %%
import requests
response = requests.request("GET", "https://api.quran.com/api/v4/resources/languages")
response.json()
# Out:
# {'languages': [{'id': 183,
#    'name': 'Yoruba',
#    'iso_code': 'yo',
#    'native_name': '',
#    'direction': 'ltr',
#    'translations_count': 1,
#    'translated_name': {'name': 'Yoruba', 'language_name': 'english'}},
#   {'id': 188,
#    'name': 'Amazigh',
#    'iso_code': 'zgh',
#    'native_name': 'Tamaziɣt',
#    'direction': 'ltr',
#    'translations_count': 1,
#    'translated_name': {'name': 'Amazigh', 'language_name': 'english'}},
#   {'id': 6,
#    'name': 'Amharic',
#    'iso_code': 'am',
#    'native_name': '',
#    'direction': 'ltr',
#    'translations_count': 2,
#    'translated_name': {'name': 'Amharic', 'language_name': 'english'}},
#   {'id': 10,
#    'name': 'Assamese',
#    'iso_code': 'as',
#    'native_name': 'অসমীয়া',
#    'direction': 'ltr',
#    'translations_count': 1,
#    'translated_name': {'name': 'Assamese', 'language_name': 'english'}},
#   {'id': 13,
#    'name': 'Azeri',
#    'iso_code': 'az',
#    'native_name': 'Azərbaycan dili',
# ...

# %%
response = requests.request("GET", "https://cartes.io/api/maps")
response.json()
# Out:
# {'current_page': 1,
#  'data': [{'slug': '49687fad-bef5-492f-a902-7c2765357818',
#    'title': 'Myanmar',
#    'description': 'Myanmar Protest Live Map',
#    'privacy': 'public',
#    'users_can_create_markers': 'yes',
#    'options': None,
#    'uuid': '49687fad-bef5-492f-a902-7c2765357818',
#    'created_at': '2021-04-08T20:28:16+02:00',
#    'updated_at': '2021-04-08T20:32:18+02:00',
#    'markers_count': 1,
#    'categories': [{'id': 147,
#      'name': 'Yangon',
#      'icon': '/images/marker-01.svg',
#      'markers_count': 1}]},
#   {'slug': '1bf42d96-239e-4d7a-9663-a456ce50cc32',
#    'title': 'Protesty w Polsce',
# ...

# %%
response = requests.request("GET", "https://api.covid19tracker.ca/summary")
response.json()
# Out:
# {'data': [{'latest_date': '2021-06-23',
#    'change_cases': '536',
#    'change_fatalities': '17',
#    'change_tests': '29851',
#    'change_hospitalizations': '-43',
#    'change_criticals': '-8',
#    'change_recoveries': '893',
#    'change_vaccinations': '406767',
#    'change_vaccinated': '359861',
#    'change_vaccines_distributed': '518000',
#    'total_cases': '1410737',
#    'total_fatalities': '26172',
#    'total_tests': '36673762',
#    'total_hospitalizations': '1059',
#    'total_criticals': '512',
#    'total_recoveries': '1374088',
#    'total_vaccinations': '33477407',
#    'total_vaccinated': '8178986',
#    'total_vaccines_distributed': '37555640'}],
#  'last_updated': '2021-06-23 13:35:02'}

# %%
import urllib.request
from urllib.request import urlopen, Request
from bs4 import BeautifulSoup 
wiki= "https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=1"
html=urlopen(wiki)
bs= BeautifulSoup(html,'lxml')
bs
#Beautiful Soup is used to extract the website page
# Out:
# <!--default_base.blade.php--><!DOCTYPE html>
# <html lang="en">
# <head>
# <title>Search | The Star</title>
# <link href="https://cdn.thestar.com.my/Themes/img/favicon.ico" rel="icon" type="image/png"/>
# <!--START: common.blade.php-->
# ...

# %%
from bs4 import BeautifulSoup 
# base_url = 'https://www.amazon.ca/s?k=watch&ref=nb_sb_noss'
base_url = 'https://www.amazon.ca/s?k=mobile&ref=nb_sb_noss'
# Add 1 because Python range.
url_list = ["{}{}".format(base_url, str(page)) for page in range(1, 10000)]
links=[]
for url in url_list:
    print (url)
    s.append(url)
# Out:
# https://www.amazon.ca/s?k=mobile&ref=nb_sb_noss1
# https://www.amazon.ca/s?k=mobile&ref=nb_sb_noss2
# https://www.amazon.ca/s?k=mobile&ref=nb_sb_noss3
# https://www.amazon.ca/s?k=mobile&ref=nb_sb_noss4
# https://www.amazon.ca/s?k=mobile&ref=nb_sb_noss5
# https://www.amazon.ca/s?k=mobile&ref=nb_sb_noss6
# https://www.amazon.ca/s?k=mobile&ref=nb_sb_noss7
# https://www.amazon.ca/s?k=mobile&ref=nb_sb_noss8
# https://www.amazon.ca/s?k=mobile&ref=nb_sb_noss9
# https://www.amazon.ca/s?k=mobile&ref=nb_sb_noss10
# https://www.amazon.ca/s?k=mobile&ref=nb_sb_noss11
# https://www.amazon.ca/s?k=mobile&ref=nb_sb_noss12
# https://www.amazon.ca/s?k=mobile&ref=nb_sb_noss13
# https://www.amazon.ca/s?k=mobile&ref=nb_sb_noss14
# https://www.amazon.ca/s?k=mobile&ref=nb_sb_noss15
# https://www.amazon.ca/s?k=mobile&ref=nb_sb_noss16
# https://www.amazon.ca/s?k=mobile&ref=nb_sb_noss17
# https://www.amazon.ca/s?k=mobile&ref=nb_sb_noss18
# https://www.amazon.ca/s?k=mobile&ref=nb_sb_noss19
# ...

# %%
from bs4 import BeautifulSoup 
base_url = 'https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno='
# Add 1 because Python range.
url_list = ["{}{}".format(base_url, str(page)) for page in range(1, 408)]
s=[]
for url in url_list:
    print (url)
    s.append(url)
# Out:
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=1
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=2
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=3
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=4
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=5
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=6
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=7
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=8
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=9
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=10
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=11
# https://www.thestar.com.my/search/?q=HIV&qsort=oldest&qrec=10&qstockcode=&pgno=12
# ...

# %%
data = []
data1= []
import csv
from urllib.request import urlopen, HTTPError
from datetime import datetime, timedelta
for pg in s:
    # query the website and return the html to the variable 'page'
    page = urllib.request.urlopen(pg)
    try:
        search_response = urllib.request.urlopen(pg)
    except urllib.request.HTTPError:
        pass
    # parse the html using beautiful soap and store in variable `soup`
    soup = BeautifulSoup(page, 'html.parser')
    # Take out the <div> of name and get its value
    ls = [x.get_text(strip=True) for x in soup.find_all("h2", {"class": "f18"})]
    ls1=  [x.get_text(strip=True) for x in soup.find_all("span", {"class": "date"})]
    # save the data in tuple
    data.append((ls))
    data1.append(ls1)
